# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\soumy\Downloads\SWYNEX-Data-Cleaning-Preparation\SWYNEX-Data-Cleaning-Preparation\data\uncleaned_dataset.csv")

# %%
df.head()
# Out:
#   Employee_ID First_Name Last_Name   Age      Department_Region    Status  \
# 0     EMP1000        Bob     Davis  25.0  Cloud Tech-California   Pending
# 1     EMP1001      Grace   Johnson  25.0        DevOps-Illinois  Inactive
# 2     EMP1002      Grace     Davis  30.0            Sales-Texas  Inactive
# 3     EMP1003      Frank   Johnson   NaN       Admin-California   Pending
# 4     EMP1004    Charlie    Miller  40.0     Finance-California  Inactive
#
#     Join_Date     Salary                    Email       Phone  \
# 0  10/12/2020  101908.53  grace.brown@example.com -9872021905
# 1   12/7/2023   89287.15    eva.brown@example.com  -724333883
# 2    7/8/2020  117004.92  frank.jones@example.com -6533410432
# 3  12/18/2024   70522.48    bob.brown@example.com -7159895654
# 4   1/17/2022   69458.15  david.jones@example.com -1103393960
#
#   Performance_Score  Remote_Work
# 0           Average         True
# 1         Excellent        False
# 2         Excellent         True
# 3              Good         True
# 4           Average         True

# %%
print("Shape:", df.shape)
print("\nData types:\n", df.dtypes)
print("\nMissing values:\n", df.isna().sum())
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Shape: (123, 12)
#
# Data types:
#  Employee_ID           object
# First_Name            object
# Last_Name             object
# Age                  float64
# Department_Region     object
# Status                object
# Join_Date             object
# Salary               float64
# Email                 object
# Phone                  int64
# Performance_Score     object
# Remote_Work             bool
# dtype: object
#
# Missing values:
#  Employee_ID           0
# First_Name            0
# Last_Name             0
# Age                  24
# Department_Region     0
# Status                0
# Join_Date             0
# Salary                4
# Email                 3
# Phone                 0
# Performance_Score     0
# Remote_Work           0
# dtype: int64
#
# Duplicate rows: 3

# %%
text_cols = ["Employee_ID","First_Name","Last_Name","Department_Region","Status","Email","Performance_Score"]
for col in text_cols:
    df[col] = df[col].astype('string').str.strip()
df['Status'] = df['Status'].str.title()
df['Performance_Score'] = df['Performance_Score'].str.title()

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# %%
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')

# %%
df['Join_Date'] = pd.to_datetime(df['Join_Date'], errors='coerce')

# %%
df['Remote_Work'] = df['Remote_Work'].astype('string').str.strip().str.lower().map({'true':True,'false':False})
parts = df['Department_Region'].str.split('-', n=1, expand=True)

# %%
df['Department'] = parts[0].str.strip()
df['Region'] = parts[1].str.strip()
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Salary'] = df['Salary'].fillna(df['Salary'].median())
df['Email'] = df['Email'].fillna('unknown@example.com')
df['Remote_Work'] = df['Remote_Work'].fillna(False)

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df = df[['Employee_ID','First_Name','Last_Name','Age','Department','Region','Status',
         'Join_Date','Salary','Email','Phone','Performance_Score','Remote_Work']]

# %%
df.to_csv(r"C:\Users\soumy\Downloads\SWYNEX-Data-Cleaning-Preparation\SWYNEX-Data-Cleaning-Preparation\data\uncleaned_dataset.csv", index=False)

# %%
print('Cleaned shape:', df.shape)
# Out:
# Cleaned shape: (120, 13)

# %%
print('Missing values remaining:', int(df.isna().sum().sum()))
# Out:
# Missing values remaining: 2

# %%
print('Duplicate rows remaining:', int(df.duplicated().sum()))
# Out:
# Duplicate rows remaining: 0

# %%
print(df.isna().sum())
# Out:
# Employee_ID          0
# First_Name           0
# Last_Name            0
# Age                  0
# Department           0
# Region               0
# Status               0
# Join_Date            2
# Salary               0
# Email                0
# Phone                0
# Performance_Score    0
# Remote_Work          0
# dtype: int64

# %%
print(df[df["Join_Date"].isna()])
# Out:
#    Employee_ID First_Name Last_Name   Age  Department      Region   Status  \
# 25     EMP1025      Frank     Jones  40.0       Admin  California   Active
# 54     EMP1054      Heidi     Davis  40.0  Cloud Tech      Nevada  Pending
#
#    Join_Date     Salary                    Email       Phone  \
# 25       NaT   65570.36  david.brown@example.com -7165179045
# 54       NaT  115987.34  alice.smith@example.com -2550233506
#
#    Performance_Score  Remote_Work
# 25         Excellent        False
# 54              Good         True

# %%
df["Join_Date"] = pd.to_datetime(df["Join_Date"], errors="coerce")

median_date = df["Join_Date"].median()

df["Join_Date"] = df["Join_Date"].fillna(median_date)

print("Median Join Date:", median_date)
# Out:
# Median Join Date: 2022-07-08 12:00:00

# %%
print(df.loc[df["Employee_ID"].isin(["EMP1025", "EMP1054"]),
             ["Employee_ID", "Join_Date"]])
# Out:
#    Employee_ID           Join_Date
# 25     EMP1025 2022-07-08 12:00:00
# 54     EMP1054 2022-07-08 12:00:00

# %%
print(df.isna().sum())
# Out:
# Employee_ID          0
# First_Name           0
# Last_Name            0
# Age                  0
# Department           0
# Region               0
# Status               0
# Join_Date            0
# Salary               0
# Email                0
# Phone                0
# Performance_Score    0
# Remote_Work          0
# dtype: int64

# %%
print('Missing values remaining:', int(df.isna().sum().sum()))
# Out:
# Missing values remaining: 0

# %%
print('Duplicate rows remaining:', int(df.duplicated().sum()))
# Out:
# Duplicate rows remaining: 0
